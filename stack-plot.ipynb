# %% [markdown]
# # Stack Plot Example Using Random Numbers

# %%
# import packages
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Create some random data to plot

# %%
x = range(1,21)
y1 = np.random.rand(20)
y2 = np.random.rand(20)

# print values to see what we have
print(x)
print(y1)
print(y2)
# Out:
# range(1, 21)
# [0.39980174 0.62568659 0.17691729 0.25288255 0.37141049 0.69727565
#  0.0493562  0.95309844 0.48928825 0.31070712 0.66701758 0.76032231
#  0.95832521 0.53723629 0.72800578 0.71954317 0.2941226  0.14256003
#  0.58469501 0.26092245]
# [0.21293138 0.49771289 0.53501357 0.39845438 0.78040434 0.5970546
#  0.60138695 0.22731502 0.06035816 0.55548086 0.84395046 0.91834068
#  0.76036185 0.14386747 0.23203071 0.35272726 0.30853262 0.23197954
#  0.76385638 0.39554857]

# %%
# setup legend for plot
plt.plot([], [], color='r', label='y1')
plt.plot ([], [], color='b', label='y2')

# setup the plot
plt.stackplot(x, y1, y2, colors= ['r', 'b'])
plt.title('Stack Plot Random Numbers')
plt.legend()
plt.show()
